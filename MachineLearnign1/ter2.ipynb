# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
iowa_path ='train.csv'
home_data=pd.read_csv(iowa_path)

# %%
home_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
y= home_data.SalePrice

# %%
feature_colums =['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']

# %%
x= home_data[feature_colums]

# %%
iowa_model =DecisionTreeRegressor()
iowa_model.fit(x,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
print('Primera predicciòn:', iowa_model.predict(x.head()))
print('Valor real',y.head().tolist())
# Out:
# Primera predicciòn: [208500. 181500. 223500. 140000. 250000.]
# Valor real [208500, 181500, 223500, 140000, 250000]

# %%
train_x,value_x,train_y,value_y = train_test_split(x,y,random_state=0)

# %%
iowa_model= DecisionTreeRegressor()
iowa_model.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
val_predictions =iowa_model.predict(value_x)

# %%
print('Prediccion: ',val_predictions)
print('valor real',value_y.tolist())
# Out:
# Prediccion:  [335000. 205000. 139000. 207500.  89500.  58500. 350000. 165000. 755000.
#  180000. 213500. 150900. 220000. 130000. 142125. 174000. 235000. 140000.
#  134000. 118500. 135000. 149000. 132500. 189000. 139000. 138887. 188000.
#   92000. 318000. 105500. 142600. 178000. 135000. 268000. 253293. 177000.
#  192500. 123000. 222500. 315750. 237500. 153000. 185500. 319000. 336000.
#  142600. 105500. 111250. 162900. 133000. 315750. 154500. 196000. 109000.
#  184000.  88000. 153575. 190000. 148000. 100000. 132000. 150000. 140000.
#  138800. 236500. 174000. 108000. 205950. 107400. 204750. 178000. 109000.
#  124000. 194500. 135750. 250000. 131500.  34900. 325300. 179900. 143000.
#  135000. 153900. 147000. 311500. 176000.  68400. 202500. 198900. 144900.
#  227000. 130500. 174000. 254900. 206000. 140000. 190000. 311500.  88000.
#  137450. 318000. 192140. 163000. 149500.  76000. 268000. 180000. 120000.
#  185000. 125500.  86000. 136500. 226000. 126000. 179400. 148500. 466500.
# ...

# %%
val_mae=mean_absolute_error(value_y,val_predictions)

# %%
print(val_mae)
# Out:
# 32255.753424657534
